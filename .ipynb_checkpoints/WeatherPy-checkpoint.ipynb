# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations / change to size 1500
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#begin processing collecting relevant data
print("Beginning Data Retrieval \n-----------------------------")
sets = 1
records = 0
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = 'imperial'

#creating lists for dataframe
weather_data = []
Citi = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

#loop through api/data
for city in cities:
    try:
        queryurl = url + 'appid=' + api_key + '&q=' + city + '&units=' + unit
        weather_resp = requests.get(queryurl).json()
        weather_data.append(weather_resp)
        Citi.append(weather_resp['name'])
        Lat.append(weather_resp['coord']['lat'])
        Lng.append(weather_resp['coord']['lon'])
        Cloudiness.append(weather_resp['clouds']['all'])
        Country.append(weather_resp['sys']['country'])
        Date.append(datetime.fromtimestamp(int(weather_resp['dt'])).isoformat())
        Humidity.append(weather_resp['main']['humidity'])
        Max_Temp.append(weather_resp['main']['temp_max'])
        Wind_Speed.append(weather_resp['wind']['speed'])
        records += 1
        print(f'Processing Record {records} of Set {sets} | {city}')
        if records == 50:
            sets += 1
            records = 0
    except (NameError, KeyError) as e:
        print('City not found. Skipping...')
print('----------------------------- \nData Retrieval Complete \n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | arroyo
# Processing Record 3 of Set 1 | te anau
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | ormara
# Processing Record 6 of Set 1 | arman
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | belaya gora
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | bacolod
# Processing Record 11 of Set 1 | rocha
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | mount gambier
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | bathsheba
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 18 of Set 1 | bjornevatn
# City not found. Skipping...
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | biloela
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | candido de abreu
# Processing Record 27 of Set 1 | san cristobal
# Processing Record 28 of Set 1 | coahuayana
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | evensk
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | lesnyye polyany
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | dzhebariki-khaya
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | cooma
# Processing Record 40 of Set 1 | lucapa
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | kapit
# Processing Record 45 of Set 1 | berlevag
# Processing Record 46 of Set 1 | ostrovnoy
# City not found. Skipping...
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | najran
# City not found. Skipping...
# Processing Record 49 of Set 1 | westport
# Processing Record 50 of Set 1 | alatri
# Processing Record 1 of Set 2 | palu
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | hofn
# Processing Record 4 of Set 2 | saldanha
# Processing Record 5 of Set 2 | batemans bay
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | geraldton
# City not found. Skipping...
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | peniche
# Processing Record 10 of Set 2 | bambanglipuro
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | manono
# Processing Record 16 of Set 2 | fiumicino
# Processing Record 17 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 18 of Set 2 | tautira
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | labuan
# Processing Record 22 of Set 2 | sorong
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | coro
# Processing Record 25 of Set 2 | pisco
# City not found. Skipping...
# Processing Record 26 of Set 2 | mogadishu
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | suntar
# Processing Record 29 of Set 2 | tayshet
# City not found. Skipping...
# Processing Record 30 of Set 2 | brawley
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | altay
# Processing Record 33 of Set 2 | vao
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | ergani
# Processing Record 36 of Set 2 | namibe
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | los tangos
# Processing Record 40 of Set 2 | matveyevka
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | inuvik
# Processing Record 43 of Set 2 | karasjok
# Processing Record 44 of Set 2 | canutama
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | provideniya
# City not found. Skipping...
# Processing Record 48 of Set 2 | bereda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | lebu
# City not found. Skipping...
# Processing Record 1 of Set 3 | shizunai
# Processing Record 2 of Set 3 | namatanai
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | igarka
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | nohar
# Processing Record 8 of Set 3 | bafq
# City not found. Skipping...
# Processing Record 9 of Set 3 | hailar
# Processing Record 10 of Set 3 | general teran
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | buala
# Processing Record 13 of Set 3 | caborca
# Processing Record 14 of Set 3 | aden
# Processing Record 15 of Set 3 | sur
# Processing Record 16 of Set 3 | qasigiannguit
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | kastamonu
# Processing Record 19 of Set 3 | flin flon
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | egvekinot
# Processing Record 22 of Set 3 | cayenne
# Processing Record 23 of Set 3 | san luis
# Processing Record 24 of Set 3 | wasilla
# City not found. Skipping...
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | salinopolis
# Processing Record 28 of Set 3 | ponerihouen
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | guerrero negro
# Processing Record 32 of Set 3 | champasak
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | elbrus
# City not found. Skipping...
# Processing Record 35 of Set 3 | boden
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | hirara
# Processing Record 38 of Set 3 | manokwari
# Processing Record 39 of Set 3 | celestun
# Processing Record 40 of Set 3 | kyzyl-mazhalyk
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | menongue
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | atuona
# Processing Record 46 of Set 3 | hayvoron
# Processing Record 47 of Set 3 | lawrence
# Processing Record 48 of Set 3 | nanortalik
# City not found. Skipping...
# Processing Record 49 of Set 3 | changtu
# Processing Record 50 of Set 3 | tombouctou
# Processing Record 1 of Set 4 | warnes
# Processing Record 2 of Set 4 | takanosu
# Processing Record 3 of Set 4 | cape town
# City not found. Skipping...
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | mezen
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | minab
# Processing Record 8 of Set 4 | ust-kuyga
# Processing Record 9 of Set 4 | kushima
# Processing Record 10 of Set 4 | obigarm
# Processing Record 11 of Set 4 | duluth
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | aripuana
# Processing Record 14 of Set 4 | kaithal
# Processing Record 15 of Set 4 | kamaishi
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | kenai
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | japura
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | sioux lookout
# Processing Record 23 of Set 4 | oriximina
# Processing Record 24 of Set 4 | hami
# Processing Record 25 of Set 4 | port hedland
# Processing Record 26 of Set 4 | tsabong
# Processing Record 27 of Set 4 | quthing
# Processing Record 28 of Set 4 | knysna
# City not found. Skipping...
# Processing Record 29 of Set 4 | hearst
# Processing Record 30 of Set 4 | hermanus
# Processing Record 31 of Set 4 | wanaka
# City not found. Skipping...
# Processing Record 32 of Set 4 | magadan
# City not found. Skipping...
# Processing Record 33 of Set 4 | lircay
# Processing Record 34 of Set 4 | vanimo
# Processing Record 35 of Set 4 | yatou
# Processing Record 36 of Set 4 | poum
# Processing Record 37 of Set 4 | koulikoro
# Processing Record 38 of Set 4 | soe
# Processing Record 39 of Set 4 | lyubinskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | berdigestyakh
# Processing Record 41 of Set 4 | hamilton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 4 | ossora
# Processing Record 43 of Set 4 | duma
# Processing Record 44 of Set 4 | caravelas
# Processing Record 45 of Set 4 | faya
# Processing Record 46 of Set 4 | khuzhir
# Processing Record 47 of Set 4 | tigil
# Processing Record 48 of Set 4 | bilma
# Processing Record 49 of Set 4 | beyneu
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | shakhovskaya
# Processing Record 2 of Set 5 | sholokhovskiy
# Processing Record 3 of Set 5 | tecoanapa
# City not found. Skipping...
# Processing Record 4 of Set 5 | samarinda
# Processing Record 5 of Set 5 | ornskoldsvik
# Processing Record 6 of Set 5 | naze
# Processing Record 7 of Set 5 | kazanskaya
# Processing Record 8 of Set 5 | kachiry
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | bilibino
# Processing Record 11 of Set 5 | gejiu
# Processing Record 12 of Set 5 | barstow
# Processing Record 13 of Set 5 | nara
# City not found. Skipping...
# Processing Record 14 of Set 5 | savalou
# Processing Record 15 of Set 5 | naifaru
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | ponta do sol
# Processing Record 18 of Set 5 | texarkana
# Processing Record 19 of Set 5 | tessalit
# Processing Record 20 of Set 5 | sumbe
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | sim
# Processing Record 23 of Set 5 | bulaevo
# Processing Record 24 of Set 5 | mahebourg
# Processing Record 25 of Set 5 | salinas
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | qaqortoq
# City not found. Skipping...
# Processing Record 28 of Set 5 | taywarah
# Processing Record 29 of Set 5 | aitape
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | do gonbadan
# Processing Record 32 of Set 5 | sterling
# Processing Record 33 of Set 5 | sitka
# Processing Record 34 of Set 5 | whithorn
# Processing Record 35 of Set 5 | troitsko-pechorsk
# Processing Record 36 of Set 5 | lobito
# Processing Record 37 of Set 5 | sual
# Processing Record 38 of Set 5 | waipawa
# Processing Record 39 of Set 5 | ayan
# City not found. Skipping...
# Processing Record 40 of Set 5 | broken hill
# Processing Record 41 of Set 5 | saint anthony
# Processing Record 42 of Set 5 | nelson bay
# Processing Record 43 of Set 5 | melchor de mencos
# City not found. Skipping...
# Processing Record 44 of Set 5 | havoysund
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | tavda
# Processing Record 47 of Set 5 | harper
# Processing Record 48 of Set 5 | saint-augustin
# Processing Record 49 of Set 5 | lagoa
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | tulun
# Processing Record 2 of Set 6 | beringovskiy
# Processing Record 3 of Set 6 | auki
# City not found. Skipping...
# Processing Record 4 of Set 6 | nantucket
# Processing Record 5 of Set 6 | fasa
# Processing Record 6 of Set 6 | sobolevo
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | kalmunai
# Processing Record 10 of Set 6 | silifke
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | ugoofaaru
# Processing Record 13 of Set 6 | mersing
# Processing Record 14 of Set 6 | manzil kamil
# Processing Record 15 of Set 6 | havelian
# Processing Record 16 of Set 6 | porvoo
# Processing Record 17 of Set 6 | moyale
# Processing Record 18 of Set 6 | gat
# Processing Record 19 of Set 6 | kaili
# Processing Record 20 of Set 6 | richards bay
# Processing Record 21 of Set 6 | rizhao
# Processing Record 22 of Set 6 | linhares
# Processing Record 23 of Set 6 | savannah bight
# Processing Record 24 of Set 6 | strezhevoy
# Processing Record 25 of Set 6 | sola
# City not found. Skipping...
# Processing Record 26 of Set 6 | poronaysk
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | tafo
# Processing Record 29 of Set 6 | necochea
# Processing Record 30 of Set 6 | kaabong
# City not found. Skipping...
# Processing Record 31 of Set 6 | sao miguel do araguaia
# Processing Record 32 of Set 6 | poya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | kavieng
# Processing Record 35 of Set 6 | bulungu
# Processing Record 36 of Set 6 | omsukchan
# City not found. Skipping...
# Processing Record 37 of Set 6 | umm lajj
# Processing Record 38 of Set 6 | ocean city
# City not found. Skipping...
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | khor
# Processing Record 41 of Set 6 | nizhniy odes
# Processing Record 42 of Set 6 | ketchikan
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | sisimiut
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | plouzane
# City not found. Skipping...
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | rangapara
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | yaan
# Processing Record 2 of Set 7 | bayshore gardens
# Processing Record 3 of Set 7 | mustasaari
# City not found. Skipping...
# Processing Record 4 of Set 7 | pitimbu
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | sabang
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | codrington
# City not found. Skipping...
# Processing Record 9 of Set 7 | goderich
# City not found. Skipping...
# Processing Record 10 of Set 7 | fare
# Processing Record 11 of Set 7 | husavik
# City not found. Skipping...
# Processing Record 12 of Set 7 | santa marta
# City not found. Skipping...
# Processing Record 13 of Set 7 | yar-sale
# Processing Record 14 of Set 7 | dabakala
# Processing Record 15 of Set 7 | coihaique
# Processing Record 16 of Set 7 | ambilobe
# Processing Record 17 of Set 7 | wanning
# Processing Record 18 of Set 7 | carmen de viboral
# City not found. Skipping...
# Processing Record 19 of Set 7 | yerofey pavlovich
# Processing Record 20 of Set 7 | upington
# Processing Record 21 of Set 7 | yangjiang
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | sao filipe
# City not found. Skipping...
# Processing Record 25 of Set 7 | laguna
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | griffith
# Processing Record 28 of Set 7 | kruisfontein
# Processing Record 29 of Set 7 | ginir
# Processing Record 30 of Set 7 | santa ines
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | dongning
# City not found. Skipping...
# Processing Record 33 of Set 7 | kaduna
# Processing Record 34 of Set 7 | arcata
# Processing Record 35 of Set 7 | sinnamary
# City not found. Skipping...
# Processing Record 36 of Set 7 | san quintin
# Processing Record 37 of Set 7 | caruray
# Processing Record 38 of Set 7 | visby
# Processing Record 39 of Set 7 | kortkeros
# Processing Record 40 of Set 7 | comodoro rivadavia
# Processing Record 41 of Set 7 | termoli
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | port-cartier
# Processing Record 44 of Set 7 | fabiansebestyen
# Processing Record 45 of Set 7 | argostolion
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | malanje
# Processing Record 48 of Set 7 | aljezur
# Processing Record 49 of Set 7 | alto araguaia
# Processing Record 50 of Set 7 | tazovskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | watsa
# Processing Record 2 of Set 8 | southbridge
# Processing Record 3 of Set 8 | curuguaty
# Processing Record 4 of Set 8 | moron
# Processing Record 5 of Set 8 | chabahar
# Processing Record 6 of Set 8 | doha
# Processing Record 7 of Set 8 | aracuai
# Processing Record 8 of Set 8 | montepuez
# Processing Record 9 of Set 8 | mercedes
# City not found. Skipping...
# Processing Record 10 of Set 8 | kloulklubed
# Processing Record 11 of Set 8 | san patricio
# Processing Record 12 of Set 8 | siteki
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | luganville
# Processing Record 15 of Set 8 | zaraza
# City not found. Skipping...
# Processing Record 16 of Set 8 | leh
# Processing Record 17 of Set 8 | zabol
# Processing Record 18 of Set 8 | oistins
# Processing Record 19 of Set 8 | cherskiy
# Processing Record 20 of Set 8 | sendafa
# Processing Record 21 of Set 8 | hualmay
# Processing Record 22 of Set 8 | arlit
# Processing Record 23 of Set 8 | portel
# Processing Record 24 of Set 8 | grand gaube
# Processing Record 25 of Set 8 | abu samrah
# Processing Record 26 of Set 8 | mar del plata
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | dongfeng
# Processing Record 29 of Set 8 | lubao
# Processing Record 30 of Set 8 | kulhudhuffushi
# Processing Record 31 of Set 8 | howard springs
# Processing Record 32 of Set 8 | sarangani
# Processing Record 33 of Set 8 | mattru
# Processing Record 34 of Set 8 | pangody
# Processing Record 35 of Set 8 | steamboat springs
# City not found. Skipping...
# Processing Record 36 of Set 8 | morondava
# Processing Record 37 of Set 8 | ixtapa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 8 | vallenar
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | namie
# Processing Record 41 of Set 8 | assiniboia
# Processing Record 42 of Set 8 | dawlatabad
# Processing Record 43 of Set 8 | riverton
# Processing Record 44 of Set 8 | nizhniy kuranakh
# City not found. Skipping...
# Processing Record 45 of Set 8 | libertador general san martin
# City not found. Skipping...
# Processing Record 46 of Set 8 | pocone
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | resistencia
# Processing Record 49 of Set 8 | moree
# City not found. Skipping...
# Processing Record 50 of Set 8 | almaznyy
# Processing Record 1 of Set 9 | daru
# Processing Record 2 of Set 9 | la rioja
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | cuenca
# City not found. Skipping...
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | van
# Processing Record 7 of Set 9 | kendari
# Processing Record 8 of Set 9 | jining
# Processing Record 9 of Set 9 | tetouan
# City not found. Skipping...
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | ambulu
# Processing Record 12 of Set 9 | tuy hoa
# Processing Record 13 of Set 9 | osimo
# Processing Record 14 of Set 9 | baruun-urt
# Processing Record 15 of Set 9 | reconquista
# Processing Record 16 of Set 9 | port hueneme
# Processing Record 17 of Set 9 | zhigalovo
# Processing Record 18 of Set 9 | portland
# Processing Record 19 of Set 9 | willowmore
# Processing Record 20 of Set 9 | sikasso
# Processing Record 21 of Set 9 | kerema
# Processing Record 22 of Set 9 | mazagao
# Processing Record 23 of Set 9 | papetoai
# Processing Record 24 of Set 9 | sambava
# Processing Record 25 of Set 9 | luanda
# Processing Record 26 of Set 9 | bukachacha
# Processing Record 27 of Set 9 | dunoon
# Processing Record 28 of Set 9 | karratha
# City not found. Skipping...
# Processing Record 29 of Set 9 | iskenderun
# Processing Record 30 of Set 9 | miraflores
# Processing Record 31 of Set 9 | aginskoye
# Processing Record 32 of Set 9 | seoul
# Processing Record 33 of Set 9 | bayir
# Processing Record 34 of Set 9 | new iberia
# Processing Record 35 of Set 9 | paamiut
# Processing Record 36 of Set 9 | yadgir
# Processing Record 37 of Set 9 | zabid
# Processing Record 38 of Set 9 | marrakesh
# City not found. Skipping...
# Processing Record 39 of Set 9 | tiznit
# Processing Record 40 of Set 9 | rio grande
# Processing Record 41 of Set 9 | belyy yar
# Processing Record 42 of Set 9 | george
# Processing Record 43 of Set 9 | gander
# Processing Record 44 of Set 9 | blagoyevo
# Processing Record 45 of Set 9 | galdar
# Processing Record 46 of Set 9 | cabo rojo
# Processing Record 47 of Set 9 | agua dulce
# Processing Record 48 of Set 9 | palmer
# Processing Record 49 of Set 9 | quelimane
# City not found. Skipping...
# Processing Record 50 of Set 9 | teya
# Processing Record 1 of Set 10 | zwedru
# Processing Record 2 of Set 10 | panguna
# Processing Record 3 of Set 10 | monrovia
# Processing Record 4 of Set 10 | araouane
# City not found. Skipping...
# Processing Record 5 of Set 10 | meulaboh
# City not found. Skipping...
# Processing Record 6 of Set 10 | wewak
# Processing Record 7 of Set 10 | san mateo del mar
# Processing Record 8 of Set 10 | yantal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 10 | kedrovyy
# Processing Record 10 of Set 10 | kalas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 10 | kibaya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 10 | isangel
# Processing Record 13 of Set 10 | hovd
# Processing Record 14 of Set 10 | lapa
# Processing Record 15 of Set 10 | neyshabur
# Processing Record 16 of Set 10 | tonder
# Processing Record 17 of Set 10 | camacha
# Processing Record 18 of Set 10 | nchelenge
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 10 | sechura
# Processing Record 20 of Set 10 | axim
# Processing Record 21 of Set 10 | ballina
# Processing Record 22 of Set 10 | camopi
# Processing Record 23 of Set 10 | concepcion
# Processing Record 24 of Set 10 | terme
# Processing Record 25 of Set 10 | katsuura
# Processing Record 26 of Set 10 | tela
# Processing Record 27 of Set 10 | tondon
# Processing Record 28 of Set 10 | nanning
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | pedra branca
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | eureka
# Processing Record 34 of Set 10 | nome
# City not found. Skipping...
# Processing Record 35 of Set 10 | baghdad
# City not found. Skipping...
# Processing Record 36 of Set 10 | northfield
# Processing Record 37 of Set 10 | half moon bay
# Processing Record 38 of Set 10 | rawson
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | mizdah
# City not found. Skipping...
# Processing Record 41 of Set 10 | lixourion
# Processing Record 42 of Set 10 | erenhot
# Processing Record 43 of Set 10 | panaba
# Processing Record 44 of Set 10 | bargarh
# Processing Record 45 of Set 10 | manzanillo
# Processing Record 46 of Set 10 | dubai
# Processing Record 47 of Set 10 | constitucion
# Processing Record 48 of Set 10 | dudinka
# Processing Record 49 of Set 10 | mandra
# Processing Record 50 of Set 10 | atar
# Processing Record 1 of Set 11 | mahibadhoo
# Processing Record 2 of Set 11 | verkhnyaya inta
# Processing Record 3 of Set 11 | san carlos de bariloche
# Processing Record 4 of Set 11 | turku
# Processing Record 5 of Set 11 | bubaque
# Processing Record 6 of Set 11 | kropotkin
# Processing Record 7 of Set 11 | ilhabela
# Processing Record 8 of Set 11 | lichuan
# Processing Record 9 of Set 11 | college
# Processing Record 10 of Set 11 | mehamn
# Processing Record 11 of Set 11 | velingara
# Processing Record 12 of Set 11 | rognan
# Processing Record 13 of Set 11 | tieli
# Processing Record 14 of Set 11 | yilan
# Processing Record 15 of Set 11 | florianopolis
# Processing Record 16 of Set 11 | alofi
# Processing Record 17 of Set 11 | san rafael del sur
# Processing Record 18 of Set 11 | aksay
# Processing Record 19 of Set 11 | olinda
# Processing Record 20 of Set 11 | ancud
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | dongsheng
# City not found. Skipping...
# Processing Record 23 of Set 11 | mindelo
# Processing Record 24 of Set 11 | priargunsk
# Processing Record 25 of Set 11 | yerbogachen
# Processing Record 26 of Set 11 | mbarara
# Processing Record 27 of Set 11 | kita
# City not found. Skipping...
# Processing Record 28 of Set 11 | hanting
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {'City':Citi, 'Cloudiness':Cloudiness, 'Country':Country, 'Date': Date, 'Humidity':Humidity, 'Lat':Lat, 'Lng':Lng,\
                'Max Temp':Max_Temp, 'Wind Speed':Wind_Speed}
weather_df = pd.DataFrame(weather_dict).count()
weather_df
# Out:
# City          528
# Cloudiness    528
# Country       528
# Date          528
# Humidity      528
# Lat           528
# Lng           528
# Max Temp      528
# Wind Speed    528
# dtype: int64

# %%
#convert into df and save output
weather_df = pd.DataFrame(weather_dict)
weather_df.dropna()
weather_df
weather_df.to_csv('output.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plot lat and max temp
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker='o', facecolor='lightblue', edgecolor='black', 
            s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs Max Temperature (Current)')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid()
plt.tight_layout()
plt.savefig('Images/latvtemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker='o', facecolor='lightblue', edgecolor='black', 
            s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs Humidity (Current)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.tight_layout()
plt.savefig('Images/latvhum.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker='o', facecolor='lightblue', edgecolor='black', 
            s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs Cloudiness (Current)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.tight_layout()
plt.savefig('Images/latvcloud.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker='o', facecolor='lightblue', edgecolor='black', 
            s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs Wind Speed (Current)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.tight_layout()
plt.savefig('Images/latvwind.png')
